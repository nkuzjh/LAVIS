# %%
# !CUDA_VISIBLE_DEVICES=1 python ../train.py --cfg-path ../lavis/projects/blip2/train/retrieval_coco_ft_vitL.yaml

# interuptted at epoch 1, because of bug

# finetune vit-L on coco retrieval epoch 1 evaluate result:
# {'txt_r1': 78.16, 'txt_r5': 94.28, 'txt_r10': 96.92, 'txt_r_mean': 89.78666666666668, 'img_r1': 63.05877648940424, 'img_r5': 85.21791283486606, 'img_r10': 90.93162734906038, 'img_r_mean': 79.7361055577769, 'r_mean': 84.76138611222179, 'agg_metrics': 89.78666666666668}

# %%
# 使用loss accumulate技巧把batchsize从默认config中的14改成paper中的224
# !CUDA_VISIBLE_DEVICES=1 python ../train.py --cfg-path ../lavis/projects/blip2/train/retrieval_coco_ft_vitL.yaml

# interuptted at epoch 1, because of bug

# finetune vit-L on coco retrieval epoch 1 evaluate result:
# {'txt_r1': 82.04, 'txt_r5': 95.34, 'txt_r10': 97.72, 'txt_r_mean': 91.7, 'img_r1': 65.88964414234306, 'img_r5': 86.56537385045982, 'img_r10': 91.91923230707717, 'img_r_mean': 81.45808343329334, 'r_mean': 86.57904171664667, 'agg_metrics': 91.7}
# Out:
# Not using distributed mode
# 2025-04-19 14:40:12,473 [INFO]
# =====  Running Parameters    =====
# 2025-04-19 14:40:12,473 [INFO] {
#     "accum_grad_iters": 16,
#     "amp": true,
#     "batch_size_eval": 16,
#     "batch_size_train": 14,
#     "beta2": 0.98,
#     "device": "cuda",
#     "dist_url": "env://",
#     "distributed": false,
#     "evaluate": false,
#     "init_lr": 5e-06,
#     "k_test": 128,
#     "lr_layer_decay": 1,
#     "lr_sched": "linear_warmup_cosine_lr",
#     "max_epoch": 5,
#     "min_lr": 0,
#     "num_workers": 4,
#     "output_dir": "output/BLIP2/Retrieval_coco_vitL_ft",
#     "resume_ckpt_path": null,
#     "save_freq": 5,
#     "save_last": true,
#     "seed": 42,
#     "task": "retrieval",
#     "train_splits": [
#         "train"
#     ],
#     "use_dist_eval_sampler": false,
#     "val_freq": 5,
#     "valid_splits": [
#         "test"
#     ],
#     "warmup_lr": 1e-08,
#     "warmup_steps": 1000,
#     "weight_decay": 0.0514,
#     "world_size": 1
# ...

# %%
# continue to finetune, resume from epoch 1 checkpoint below
# !CUDA_VISIBLE_DEVICES=1 python ../train.py --cfg-path ../lavis/projects/blip2/train/retrieval_coco_ft_vitL.yaml
# Out:
# Not using distributed mode
# 2025-04-22 02:02:05,701 [INFO]
# =====  Running Parameters    =====
# 2025-04-22 02:02:05,702 [INFO] {
#     "accum_grad_iters": 16,
#     "amp": true,
#     "batch_size_eval": 16,
#     "batch_size_train": 14,
#     "beta2": 0.98,
#     "device": "cuda",
#     "dist_url": "env://",
#     "distributed": false,
#     "evaluate": false,
#     "init_lr": 5e-06,
#     "k_test": 128,
#     "lr_layer_decay": 1,
#     "lr_sched": "linear_warmup_cosine_lr",
#     "max_epoch": 5,
#     "min_lr": 0,
#     "num_workers": 4,
#     "output_dir": "output/BLIP2/Retrieval_coco_vitL_ft",
#     "resume_ckpt_path": "/home/zhh/ssd/excute/deeplearning/projects/TTA_MM_Retrieval/LAVIS/lavis/output/BLIP2/Retrieval_coco_vitL_ft/20250419144/checkpoint_0.pth",
#     "save_freq": 5,
#     "save_last": true,
#     "seed": 42,
#     "task": "retrieval",
#     "train_splits": [
#         "train"
#     ],
#     "use_dist_eval_sampler": false,
#     "val_freq": 5,
# ...

# %%
# command to resume training from epoch 1 checkpoint is in train.py
